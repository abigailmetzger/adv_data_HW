# %%
#imported the libraries
import matplotlib as plot
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
session = Session(engine)

# %%
mostrecent_date,  = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(type(mostrecent_date))
# Out:
# <class 'str'>

# %%
import datetime as dt
from datetime import datetime

# %%
print(mostrecent_date)
mostrecent_date = datetime.strptime(mostrecent_date, "%Y-%m-%d")
# Out:
# 2017-08-23

# %%
#yearago_date = mostrecent_date-dt.timedelta(days = 365)
#print(yearago_date)

# %%
yearago_2016 = session.query(Measurement.date, Measurement.prcp).all()
yearago_2016
# Out:
# [('2010-01-01', 0.08),
#  ('2010-01-02', 0.0),
#  ('2010-01-03', 0.0),
#  ('2010-01-04', 0.0),
#  ('2010-01-06', None),
#  ('2010-01-07', 0.06),
#  ('2010-01-08', 0.0),
#  ('2010-01-09', 0.0),
#  ('2010-01-10', 0.0),
#  ('2010-01-11', 0.01),
#  ('2010-01-12', 0.0),
#  ('2010-01-14', 0.0),
#  ('2010-01-15', 0.0),
#  ('2010-01-16', 0.0),
#  ('2010-01-17', 0.0),
#  ('2010-01-18', 0.0),
#  ('2010-01-19', 0.0),
#  ('2010-01-20', 0.0),
#  ('2010-01-21', 0.0),
#  ('2010-01-22', 0.0),
#  ('2010-01-23', 0.0),
#  ('2010-01-24', 0.01),
#  ('2010-01-25', 0.0),
#  ('2010-01-26', 0.04),
#  ('2010-01-27', 0.12),
#  ('2010-01-28', 0.0),
#  ('2010-01-30', None),
#  ('2010-01-31', 0.03),
#  ('2010-02-01', 0.01),
#  ('2010-02-03', None),
#  ('2010-02-04', 0.01),
#  ('2010-02-05', 0.0),
#  ('2010-02-06', 0.0),
#  ('2010-02-07', 0.0),
#  ('2010-02-08', 0.0),
#  ('2010-02-09', 0.0),
#  ('2010-02-11', 0.0),
#  ('2010-02-12', 0.02),
#  ('2010-02-13', 0.01),
#  ('2010-02-14', 0.0),
#  ('2010-02-15', 0.0),
# ...

# %%
df_2016 = pd.DataFrame(yearago_2016, columns=['date', 'precipitation'])
#df_2016 = df_2016.set_index('date')
df_2016.head()
# Out:
#          date  precipitation
# 0  2010-01-01           0.08
# 1  2010-01-02           0.00
# 2  2010-01-03           0.00
# 3  2010-01-04           0.00
# 4  2010-01-06            NaN

# %%
pd.to_datetime(df_2016['date'])
# Out:
# 0       2010-01-01
# 1       2010-01-02
# 2       2010-01-03
# 3       2010-01-04
# 4       2010-01-06
# 5       2010-01-07
# 6       2010-01-08
# 7       2010-01-09
# 8       2010-01-10
# 9       2010-01-11
# 10      2010-01-12
# 11      2010-01-14
# 12      2010-01-15
# 13      2010-01-16
# 14      2010-01-17
# 15      2010-01-18
# 16      2010-01-19
# 17      2010-01-20
# 18      2010-01-21
# 19      2010-01-22
# 20      2010-01-23
# 21      2010-01-24
# 22      2010-01-25
# 23      2010-01-26
# 24      2010-01-27
# 25      2010-01-28
# 26      2010-01-30
# 27      2010-01-31
# 28      2010-02-01
# 29      2010-02-03
#            ...
# 19520   2017-07-24
# 19521   2017-07-25
# 19522   2017-07-26
# 19523   2017-07-27
# 19524   2017-07-28
# 19525   2017-07-29
# 19526   2017-07-30
# 19527   2017-07-31
# 19528   2017-08-01
# 19529   2017-08-02
# 19530   2017-08-03
# 19531   2017-08-05
# 19532   2017-08-06
# 19533   2017-08-07
# 19534   2017-08-08
# 19535   2017-08-09
# ...

# %%
df_2016['date'] = pd.to_datetime(df_2016['date'])  
mask = (df_2016['date'] > 2016-8-23) & (df_2016['date'] <= 2017-8-23)
df = df_2016.loc[mask]
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a436396d9d2b> in <module>
#       1 df_2016['date'] = pd.to_datetime(df_2016['date'])
# ----> 2 mask = (df_2016['date'] > 2016-8-23) & (df_2016['date'] <= 2017-8-23)
#       3 df = df_2016.loc[mask]
#       4 print(df)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1228
#    1229             res_values = dispatch_to_index_op(op, self, other,
# -> 1230                                               pd.DatetimeIndex)
#    1231
#    1232             return self._constructor(res_values, index=self.index,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1099         left_idx = left_idx._shallow_copy(freq=None)
#    1100     try:
# -> 1101         result = op(left_idx, right)
# ...
